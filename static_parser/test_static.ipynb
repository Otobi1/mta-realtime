# %%
# !wget https://rrgtfsfeeds.s3.amazonaws.com/gtfs_subway.zip
# !wget https://rrgtfsfeeds.s3.amazonaws.com/gtfs_supplemented.zip
# Out:
# --2025-01-15 20:47:18--  https://rrgtfsfeeds.s3.amazonaws.com/gtfs_subway.zip
# Resolving rrgtfsfeeds.s3.amazonaws.com (rrgtfsfeeds.s3.amazonaws.com)... 16.182.73.57, 52.216.185.99, 16.182.101.9, ...
# Connecting to rrgtfsfeeds.s3.amazonaws.com (rrgtfsfeeds.s3.amazonaws.com)|16.182.73.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5745248 (5.5M) [application/zip]
# Saving to: ‘gtfs_subway.zip’
#
# gtfs_subway.zip     100%[===================>]   5.48M  5.60MB/s    in 1.0s
#
# 2025-01-15 20:47:20 (5.60 MB/s) - ‘gtfs_subway.zip’ saved [5745248/5745248]
#
# --2025-01-15 20:47:20--  https://rrgtfsfeeds.s3.amazonaws.com/gtfs_supplemented.zip
# Resolving rrgtfsfeeds.s3.amazonaws.com (rrgtfsfeeds.s3.amazonaws.com)... 52.216.207.83, 52.216.185.99, 16.182.101.9, ...
# Connecting to rrgtfsfeeds.s3.amazonaws.com (rrgtfsfeeds.s3.amazonaws.com)|52.216.207.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
import os
import pandas as pd

# %%
df = pd.read_csv("gtfs_subway/agency.txt")
df
# Out:
#   agency_id                agency_name           agency_url   agency_timezone  \
# 0  MTA NYCT  MTA New York City Transit  http://www.mta.info  America/New_York
#
#   agency_lang  agency_phone
# 0          en  718-330-1234

# %%
df = pd.read_csv("gtfs_subway/calendar.txt")
df
# Out:
#   service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0     Sunday       0        0          0         0       0         0       1
# 1   Saturday       0        0          0         0       0         1       0
# 2    Weekday       1        1          1         1       1         0       0
# 3  Weekday-1       1        1          1         1       1         0       0
# 4  Weekday-2       1        1          1         1       1         0       0
#
#    start_date  end_date
# 0    20250118  20250518
# 1    20250118  20250518
# 2    20250118  20250518
# 3    20250118  20250214
# 4    20250218  20250518

# %%
df = pd.read_csv("gtfs_subway/routes.txt")
df
# Out:
#    agency_id route_id route_short_name                  route_long_name  \
# 0   MTA NYCT        1                1        Broadway - 7 Avenue Local
# 1   MTA NYCT        2                2                 7 Avenue Express
# 2   MTA NYCT        3                3                 7 Avenue Express
# 3   MTA NYCT        4                4         Lexington Avenue Express
# 4   MTA NYCT        5                5         Lexington Avenue Express
# 5   MTA NYCT       5X               5X         Lexington Avenue Express
# 6   MTA NYCT        6                6           Lexington Avenue Local
# 7   MTA NYCT       6X               6X          Pelham Bay Park Express
# 8   MTA NYCT        7                7                   Flushing Local
# 9   MTA NYCT       7X               7X                 Flushing Express
# 10  MTA NYCT        A                A                 8 Avenue Express
# 11  MTA NYCT        B                B                 6 Avenue Express
# ...

# %%
df = pd.read_csv("gtfs_subway/shapes.txt")
df
# Out:
#        shape_id  shape_pt_sequence  shape_pt_lat  shape_pt_lon
# 0       1..N03R                  0     40.702068    -74.013664
# 1       1..N03R                  1     40.703199    -74.014792
# 2       1..N03R                  2     40.703226    -74.014820
# 3       1..N03R                  3     40.703253    -74.014846
# 4       1..N03R                  4     40.703280    -74.014870
# ...         ...                ...           ...           ...
# 176477  SI.S31R                685     40.513696    -74.250493
# 176478  SI.S31R                686     40.513579    -74.250706
# 176479  SI.S31R                687     40.513458    -74.250917
# 176480  SI.S31R                688     40.513334    -74.251124
# 176481  SI.S31R                689     40.512764    -74.251961
#
# [176482 rows x 4 columns]

# %%
df = pd.read_csv("gtfs_subway/transfers.txt")
df
# Out:
#     from_stop_id to_stop_id  transfer_type  min_transfer_time
# 0            101        101              2                180
# 1            103        103              2                180
# 2            104        104              2                180
# 3            106        106              2                180
# 4            107        107              2                180
# ..           ...        ...            ...                ...
# 611          S01        A45              2                180
# 612          S01        S01              2                180
# 613          S03        S03              2                180
# 614          S04        239              2                180
# 615          S04        S04              2                180
#
# [616 rows x 4 columns]
